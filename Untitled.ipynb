# %%
pip install PyMongo
# Out:
# ...
#    ---------------------------------------- 0.0/926.7 kB ? eta -:--:--
#    - ------------------------------------- 30.7/926.7 kB 640.0 kB/s eta 0:00:02
#    --- ----------------------------------- 71.7/926.7 kB 777.7 kB/s eta 0:00:02
#    ------ --------------------------------- 143.4/926.7 kB 1.1 MB/s eta 0:00:01
#    -------- ------------------------------- 194.6/926.7 kB 1.1 MB/s eta 0:00:01
#    ---------- ----------------------------- 235.5/926.7 kB 1.0 MB/s eta 0:00:01
#    ------------ --------------------------- 286.7/926.7 kB 1.1 MB/s eta 0:00:01
#    --------------- ------------------------ 358.4/926.7 kB 1.1 MB/s eta 0:00:01
#    ------------------ --------------------- 419.8/926.7 kB 1.1 MB/s eta 0:00:01
#    -------------------- ------------------- 471.0/926.7 kB 1.2 MB/s eta 0:00:01
#    ------------------------ --------------- 563.2/926.7 kB 1.2 MB/s eta 0:00:01
#    ------------------------- -------------- 583.7/926.7 kB 1.1 MB/s eta 0:00:01
# ...

# %%
import pymongo

# %%
server = pymongo.MongoClient('mongodb://localhost:27017')
server
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db = server['Web']
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'Web')

# %%
col = db['net']
col
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'Web'), 'net')

# %%
col.insert_many([{'Name':'Ridhima','Age':21,'Sal':120000},
     {'Name':'Nishi','Age':29,'Sal':220000},
     {'Name':'Vinit','Age':22,'Sal':150000}])
# Out:
# InsertManyResult([ObjectId('671fa87e213e85e3fbced32b'), ObjectId('671fa87e213e85e3fbced32c'), ObjectId('671fa87e213e85e3fbced32d')], acknowledged=True)

# %%
col.update_one({'Name':'Vinit'},{'$set':{'Sal':50000}})
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
col.update_many({'Age':29},{'$set':{'Sal':500000}})
# Out:
# UpdateResult({'n': 2, 'nModified': 2, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
server.drop_database('Web')

# %%
import pandas as pd
df = pd.read_csv('titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data = df.to_dict(orient='records')
data
# Out:
# [{'PassengerId': 1,
#   'Survived': 0,
#   'Pclass': 3,
#   'Name': 'Braund, Mr. Owen Harris',
#   'Gender': 'male',
#   'Age': 22.0,
#   'SibSp': 1,
#   'Parch': 0,
#   'Ticket': 'A/5 21171',
#   'Fare': 7.25,
#   'Cabin': nan,
#   'Embarked': 'S'},
#  {'PassengerId': 2,
#   'Survived': 1,
#   'Pclass': 1,
#   'Name': 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#   'Gender': 'female',
#   'Age': 38.0,
#   'SibSp': 1,
#   'Parch': 0,
#   'Ticket': 'PC 17599',
#   'Fare': 71.2833,
#   'Cabin': 'C85',
#   'Embarked': 'C'},
#  {'PassengerId': 3,
#   'Survived': 1,
#   'Pclass': 3,
#   'Name': 'Heikkinen, Miss. Laina',
#   'Gender': 'female',
#   'Age': 26.0,
#   'SibSp': 0,
#   'Parch': 0,
#   'Ticket': 'STON/O2. 3101282',
#   'Fare': 7.925,
#   'Cabin': nan,
#   'Embarked': 'S'},
#  {'PassengerId': 4,
#   'Survived': 1,
#   'Pclass': 1,
#   'Name': 'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#   'Gender': 'female',
#   'Age': 35.0,
#   'SibSp': 1,
#   'Parch': 0,
# ...

# %%
db.net.insert_many(data)
# Out:
# InsertManyResult([ObjectId('671fa896213e85e3fbced32e'), ObjectId('671fa896213e85e3fbced32f'), ObjectId('671fa896213e85e3fbced330'), ObjectId('671fa896213e85e3fbced331'), ObjectId('671fa896213e85e3fbced332'), ObjectId('671fa896213e85e3fbced333'), ObjectId('671fa896213e85e3fbced334'), ObjectId('671fa896213e85e3fbced335'), ObjectId('671fa896213e85e3fbced336'), ObjectId('671fa896213e85e3fbced337'), ObjectId('671fa896213e85e3fbced338'), ObjectId('671fa896213e85e3fbced339'), ObjectId('671fa896213e85e3fbced33a'), ObjectId('671fa896213e85e3fbced33b'), ObjectId('671fa896213e85e3fbced33c'), ObjectId('671fa896213e85e3fbced33d'), ObjectId('671fa896213e85e3fbced33e'), ObjectId('671fa896213e85e3fbced33f'), ObjectId('671fa896213e85e3fbced340'), ObjectId('671fa896213e85e3fbced341'), ObjectId('671fa896213e85e3fbced342'), ObjectId('671fa896213e85e3fbced343'), ObjectId('671fa896213e85e3fbced344'), ObjectId('671fa896213e85e3fbced345'), ObjectId('671fa896213e85e3fbced346'), ObjectId('671fa896213e85e3fbce
# ...

# %%
pip install PyMysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql

# %%
import sqlalchemy as sa

# %%
con = sa.create_engine('mysql+pymysql://root:firstPython1234@localhost:3306/sales')
con
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/sales)

# %%
pd.read_sql('show databases',con)
# Out:
#               Database
# 0                    a
# 1                  aim
# 2               carbha
# 3                   db
# 4                 deer
# 5                 desk
# 6                 exam
# 7              feature
# 8                field
# 9   information_schema
# 10             journey
# 11                main
# 12             mission
# 13                 mob
# 14               mysql
# 15                   n
# 16                 new
# 17  performance_schema
# 18               query
# 19               queue
# 20          redemption
# 21                ring
# 22               sales
# 23            scrutiny
# 24               spend
# 25               start
# 26                 sys
# 27                task
# 28                test
# 29                text
# 30                tool
# 31                 val
# 32                view
# 33               views
# 34              vision
# 35               wheel

# %%
pd.read_sql_query('show tables',con)
# Out:
#     Tables_in_sales
# 0             bench
# 1             child
# 2            child1
# 3          comapany
# 4           company
# ..              ...
# 101           wal_1
# 102           wal_2
# 103             wfh
# 104           wheel
# 105           world
#
# [106 rows x 1 columns]

# %%
pd.read_sql('wfh',con)
# Out:
#    id  age  Aadhar
# 0   1    2       3
# 1   5    3       4
# 2   5    6       7
# 3   8    9       0

# %%
pd.read_sql_table('wfh',con)
# Out:
#    id  age  Aadhar
# 0   1    2       3
# 1   5    3       4
# 2   5    6       7
# 3   8    9       0

# %%
pd.read_sql_query('show create table wfh',con)
# Out:
#   Table                                       Create Table
# 0   wfh  CREATE TABLE `wfh` (\n  `id` int DEFAULT NULL,...

# %%
pd.read_sql('select * from wfh',con)
# Out:
#    id  age  Aadhar
# 0   1    2       3
# 1   5    3       4
# 2   5    6       7
# 3   8    9       0
